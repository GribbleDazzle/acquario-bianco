# %% [markdown]
# Basic imports and setup

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import math
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# # Group-by

# %% [markdown]
# ### Exercise 1
#
# Consider the following Series

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
          'Oregon', 'Nevada', 'California', 'Idaho']
data = pd.Series(np.random.randn(8), index=states)
data[['Vermont', 'Nevada', 'Idaho']] = np.nan
data
# Out:
# Ohio         -0.204708
# New York      0.478943
# Vermont            NaN
# Florida      -0.555730
# Oregon        1.965781
# Nevada             NaN
# California    0.092908
# Idaho              NaN
# dtype: float64

# %% [markdown]
# Given that 'Ohio', 'New York', 'Vermont' and 'Florida' are East states and the other are West states, fill the NaN values with the mean value of the states belonging to the same group. This means that the value corresponding to 'Vermont' should be filled with the average of East states and the value corresponding to 'Nevada' with the average of West states by using the groupby mechanism (see chapter 10.3 Apply: General split-apply-combine)

# %% [markdown]
# ##### Solution

# %%
# Out:
# Ohio         -0.204708
# New York      0.478943
# Vermont      -1.000000
# Florida      -0.555730
# Oregon        1.965781
# Nevada        1.000000
# California    0.092908
# Idaho         1.000000
# dtype: float64

# %% [markdown]
# ### Exercise 2
#
# Using again the previous series, fill all the NaN values of East states with the value -1 and all the NaN values of west states with value 1

# %% [markdown]
# ##### Solution

# %% [markdown]
# ### Exercise 3
# Consider the following Series, representing a deck of cards where the index is the name of the card and the value its score (note that all figures score 10):

# %%
# Hearts, Spades, Clubs, Diamonds
suits = ['H', 'S', 'C', 'D']
card_val = (list(range(1, 11)) + [10] * 3) * 4
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in ['H', 'S', 'C', 'D']:
    cards.extend([str(num) + suit for num in base_names])

deck = pd.Series(card_val, index=cards)
deck
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
#        ..
# 9D      9
# 10D    10
# JD     10
# KD     10
# QD     10
# Length: 52, dtype: int64

# %% [markdown]
# write:
#
# * a function that draws an arbitrary number of cards from the deck
# * a function that draw an arbitrary number of cards for each suit
# * a function updating the deck mapping card names to tuples (i.e. 10C -> ('C','10') )

# %% [markdown]
# #####Solution

# %%
# Out:
# C  5C     5
#    6C     6
#    AC     1
# D  5D     5
#    6D     6
#    7D     7
# H  JH    10
#    5H     5
#    KH    10
# S  JS    10
#    KS    10
#    7S     7
# dtype: int64

# %% [markdown]
# ### Exercise 4
#
# consider the following DataFrame

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a',
                                'b', 'b', 'b', 'b'],
                   'data': np.random.randn(8),
                   'weights': np.random.rand(8)})
df
# Out:
#   category      data   weights
# 0        a -0.011862  0.495172
# 1        a  1.004812  0.915094
# 2        a  1.327195  0.945372
# 3        a -0.919262  0.533232
# 4        b -1.549106  0.252493
# 5        b  0.022185  0.720862
# 6        b  0.758363  0.367439
# 7        b -0.660524  0.498648

# %% [markdown]
# For each category compute the weighted mean of data (using the weights colum for weights)

# %% [markdown]
# ##### Solution

# %% [markdown]
# # Plotting
#
# Download vaccination data of italian regions from https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-latest.csv and perform the following analysis:
#
# 1.   Use a bar plot to display the number of first doses (prima_dose) for each age range (fascia_anagrafica) and sex (sesso_maschile, sesso_femminile).
# 2.   Use a pie plot to diaplay the distribution of booster doses  (dose_addizionale_booster) among the different age ranges.
# 3.   Plot the daily and weekly first doses of the last six months. Insert some annotation on the plot (e.g. the date for the mandatory greepass on work place).
# 4.   Display on the same plot the first and second doses trend for 2021. Is there any correlation?
#      *    Find the average delay of the second doese (use a cross correlation strategy)  from the first. Explore if it behaves costantly in the different periods (e.g. before and after March 2021)
#      *    Find the average delay for each different vaccine (fornitore).
# 5.   Compute and display the percentage of population that got the second dose for each region. (Find a reliable external source to get the population of each region)

# %%
#Example of expected output for 1

# %%
#Example of expected output for 2

# %%
#Example of expected output for 3 (just daily)

# %%
#Example of expected output for 4a (weakly)
# Out:
# The average delay is of 5 W

# %%
#Example of expected output for 4b (weakly)
# Out:
# ###################  Janssen  #######################
# The average delay for Janssen is of -80 W
# ###################  Moderna  #######################
# The average delay for Moderna is of 5 W
# ###################  Pfizer/BioNTech  #######################
# The average delay for Pfizer/BioNTech is of 5 W
# ###################  Vaxzevria (AstraZeneca)  #######################
# The average delay for Vaxzevria (AstraZeneca) is of 11 W

# %%
#Example of expected output for 5 (not completed)
# Out:
# (60.0, 80.0)

# %% [markdown]
# Solution

# %%
# Out:
#        data_somministrazione        fornitore  ... codice_regione_ISTAT nome_area
# 0                 2020-12-27          Moderna  ...                   19   Sicilia
# 1                 2020-12-27  Pfizer/BioNTech  ...                   13   Abruzzo
# 2                 2020-12-27  Pfizer/BioNTech  ...                   13   Abruzzo
# 3                 2020-12-27  Pfizer/BioNTech  ...                   13   Abruzzo
# 4                 2020-12-27  Pfizer/BioNTech  ...                   13   Abruzzo
# ...                      ...              ...  ...                  ...       ...
# 175180            2022-01-16  Pfizer/BioNTech  ...                    5    Veneto
# 175181            2022-01-16  Pfizer/BioNTech  ...                    5    Veneto
# 175182            2022-01-16  Pfizer/BioNTech  ...                    5    Veneto
# 175183            2022-01-16  Pfizer/BioNTech  ...                    5    Veneto
# ...

# %%
#Solution of 1

# %%
#Solution of 2

# %%
#Solution of 3

# %%
#Solution of 4a
# Out:
# The average delay is of 5 W

# %%
#Solution of 4b
# Out:
# ###################  Janssen  #######################
# The average delay for Janssen is of -140 W
# ###################  Moderna  #######################
# The average delay for Moderna is of 5 W
# ###################  Pfizer Pediatrico  #######################
# The average delay for Pfizer Pediatrico is of 0 W
# ###################  Pfizer/BioNTech  #######################
# The average delay for Pfizer/BioNTech is of 5 W
# ###################  Vaxzevria (AstraZeneca)  #######################
# The average delay for Vaxzevria (AstraZeneca) is of 11 W

# %%
#Solution of 5
# Out:
# (60.0, 80.0)
